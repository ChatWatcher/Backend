# %%
from chat_downloader import ChatDownloader
import pandas
import json

url = 'https://www.twitch.tv/videos/1469302943'


def getChatLogs():
    # Download chat logs
    chat = ChatDownloader().get_chat(url)

    # Insert data into dataframe
    data = []
    for obj in chat:
        data.append(obj['message'])

    # return dataframe from array
    return pandas.DataFrame(data)

df = getChatLogs()

df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20704/3787169160.py in <module>
#      18     return pandas.DataFrame(data)
#      19
# ---> 20 df = getChatLogs()
#      21
#      22 df.head(10)
#
# ~\AppData\Local\Temp/ipykernel_20704/3787169160.py in getChatLogs()
#      12     # Insert data into dataframe
#      13     data = []
# ---> 14     for obj in chat:
#      15         data.append(obj['message'])
#      16
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\chat_downloader\sites\common.py in __next__(self)
#     281         """
#     282         try:
# --> 283             item = next(self.chat)
#     284
#     285             if self._output_writer is not None:  # writer has been attached
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\chat_downloader\sites\twitch.py in _get_chat_messages_by_vod_id(self, vod_id, params, max_duration, offset)
#    1172             for attempt_number in attempts(max_attempts):
#    1173                 try:
# -> 1174                     info = self._session_get_json(url)
#    1175                     break
#    1176                 except (JSONDecodeError, RequestException) as e:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\chat_downloader\sites\common.py in _session_get_json(self, url, **kwargs)
#     510     def _session_get_json(self, url, **kwargs):
#     511         """Make a get request using the current session and return as JSON."""
# --> 512         return self._session_get(url, **kwargs).json()
#     513
#     514     def get_site_value(self, value):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\chat_downloader\sites\common.py in _session_get(self, url, **kwargs)
#     506     def _session_get(self, url, **kwargs):
#     507         """Make a get request using the current session."""
# --> 508         return self.session.get(url, **kwargs)
#     509
#     510     def _session_get_json(self, url, **kwargs):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     540
#     541         kwargs.setdefault('allow_redirects', True)
# --> 542         return self.request('GET', url, **kwargs)
#     543
#     544     def options(self, url, **kwargs):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in getresponse(self)
#    1343         try:
#    1344             try:
# -> 1345                 response.begin()
#    1346             except ConnectionError:
#    1347                 self.close()
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
